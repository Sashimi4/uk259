# %%
import pandas as pd
import numpy as np
df=pd.read_csv("../datasets/melb_data.csv")
#df[df.isnull().any(axis=1)].iloc[-5:,14:17]
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
## Pandas
Pandas is a Data Manipulaiton Library hat makes it easy to handle complex datasets.

Creating a DataFrame by passing a NumPy array, with labeled columns:

# %%
df = pd.DataFrame(np.random.randn(6, 4),  columns=list("ABCD"))

# %% [markdown]
# The columns of the resulting DataFrame have different dtypes.
#
# If you’re using IPython, tab completion for column names (as well as public attributes) is automatically enabled. Here’s a subset of the attributes that will be completed:

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %% [markdown]
# ## Viewing data
# df.head()
# df.tail(3)
# df.describe()
# df.sort_values(by="B")
# df.sort_index(axis=1, ascending=False)

# %% [markdown]
# ## Selecting Data

# %%
print(df["A"])

print(df.iloc[3:5, 0:2] )#selection by index
# Out:
# 0    0.711198
# 1    0.326552
# 2    1.182634
# 3    1.305521
# 4    0.302218
# 5   -0.251031
# Name: A, dtype: float64
#           A         B
# 3  1.305521  0.713508
# 4  0.302218  2.265124

# %% [markdown]
# ## Boolean indexing

# %%
print(df[df > 0])
# Out:
#           A         B         C         D
# 0  0.711198       NaN  0.230388  0.227714
# 1  0.326552       NaN       NaN  0.104969
# 2  1.182634  1.185896  0.658286       NaN
# 3  1.305521  0.713508       NaN  0.048853
# 4  0.302218  2.265124  0.684564  0.350826
# 5       NaN  1.324972  1.760301  0.908176

# %%
df.iloc[1,1] = "Hello"

df[df.isin(["Hello", "World"])]
# Out:
#     A      B   C   D
# 0 NaN    NaN NaN NaN
# 1 NaN  Hello NaN NaN
# 2 NaN    NaN NaN NaN
# 3 NaN    NaN NaN NaN
# 4 NaN    NaN NaN NaN
# 5 NaN    NaN NaN NaN

# %% [markdown]
# ## Task1: Missing data
# In the following Dataframe, some data is missing. Find a way to:
# * 1: Remove the column containing the missing data
# * 2:  Fill the missing column with the average of each row

# %%
df1 = df.reindex( columns=list(df.columns) + ["E"])
df1.reindex(columns=list(df1.columns) + ["empty columns"])
df["task 2"]= np.random.choice(["small", "medium", "large"], df.shape[0])
df1.dropna(axis=1, how='any')
#df1
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Landsize  \
# ...

# %% [markdown]
# # Task 2.1: Plotting
#
# The variable *ts* below contains a randomly generated "time series" a dataset in which time is one of the axies.
#
# * Calculate the **cumulative sum** of this series in a new series. The cumulative sum at index *i* is the sum of all entries in *ts* up until index *i*.
# * Plot the cumulative sum using *matplotlib*

# %%
import matplotlib.pyplot as plt
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts1 = ts.cumsum()
plt.plot(ts1)

# %% [markdown]
# # Task 2.2:
#
# Adapt the code above to plot 4 timeseries in the same plot, with A different colour and label for each timeseries.\
# The output should look similar to this:\
# ![ ](..\img\output_2_2.png)

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
);
df2 = df.cumsum()
plt.plot(df2)

# %% [markdown]
# # Plot sections for Presenation
# > Plot 1 ... *title here*

# %%
# Ausgangsliste
df=pd.read_csv("../datasets/melb_data.csv")
originalList = df
originalList
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
import pandas as pd
import numpy as np
import scipy as scipy
import seaborn as sns; sns.set_theme(color_codes=True)

outlierGraph = pd.read_csv("../datasets/melb_data.csv")

outlierGraph.dropna(axis=0, how='any')
outlierGraph["Landsize"] = scipy.stats.zscore(outlierGraph["Landsize"])
outlierGraph[["Landsize","Rooms"]]

# Outlier problem 
ax = sns.regplot(x="Landsize", y="Rooms", data=outlierGraph)

# %%
import pandas as pd
import numpy as np
import scipy as scipy
import seaborn as sns; sns.set_theme(color_codes=True)

df = pd.read_csv("../datasets/melb_data.csv")

df["SellerG"].value_counts()


# Seller amount
ax = sns.regplot(x="Landsize", y="Rooms", data=df)

# %% [markdown]
# # Which Seller sold the most houses ever

# %%
import pandas as pd
import numpy as np
import scipy as scipy
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_theme(color_codes=True)

df = pd.read_csv("../datasets/melb_data.csv")



#df["SellerG"].value_counts()
#df["SellerG"].unique()

sellers = pd.DataFrame()
sellers["Amount Sold"] = df["SellerG"].value_counts()
sellers.index.name = "Seller names"
sellers.reset_index(inplace=True)
sellers.dropna(axis=1, how='any')
sellers.iloc[2:6]

#df[["Amount Sold", "SellerG"]]

# Top 17 Sellers
sns.barplot(x="Amount Sold", y="Seller names", data=sellers.iloc[2:17], color="salmon", estimator=np.median)
# Out:
# <AxesSubplot:xlabel='Amount Sold', ylabel='Seller names'>

# %% [markdown]
# # Most wanted Suburb area

# %%
import pandas as pd
import numpy as np
import scipy as scipy
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_theme(color_codes=True)

df = pd.read_csv("../datasets/melb_data.csv")

suburbs = pd.DataFrame()
suburbs["Amount sold in that suburb"] = df["Suburb"].value_counts()
suburbs.index.name = "Suburb name"
suburbs.reset_index(inplace=True)
suburbs.dropna(axis=1, how='any')
suburbs.iloc[2:6]

# Top 17 Sellers
sns.barplot(x="Amount sold in that suburb", y="Suburb name", data=suburbs.iloc[2:17], color="green", estimator=np.median)
# Out:
# <AxesSubplot:xlabel='Amount sold in that suburb', ylabel='Suburb name'>

# %% [markdown]
# # Average Car amount per suburb

# %%
import pandas as pd
import numpy as np
import scipy as scipy
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_theme(color_codes=True)

df = pd.read_csv("../datasets/melb_data.csv")

suburbs = pd.DataFrame()
suburbs["Amount sold in that suburb"] = df["Suburb"].value_counts()
suburbs["Amount of cars"] = 
suburbs.index.name = "Suburb name"
suburbs.dropna(axis=1, how='any')
suburbs.reset_index(inplace=True)
suburbs[["Suburb name", "Amount sold in that suburb", "Amount of cars"]].iloc[2:20]

# Top 17 Sellers
#sns.barplot(x="Amount sold in that suburb", y="Suburb name", data=suburbs.iloc[2:17], color="green", estimator=np.median)
# Out:
#        Suburb name  Amount sold in that suburb  Amount of cars
# 2   Bentleigh East                         249               1
# 3          Preston                         239               1
# 4        Brunswick                         222               1
# 5         Essendon                         220               1
# 6      South Yarra                         202               1
# 7        Glen Iris                         195               1
# 8         Hawthorn                         191               1
# 9           Coburg                         190               1
# 10       Northcote                         188               1
# 11        Brighton                         186               1
# 12             Kew                         177               1
# 13     Pascoe Vale                         171               1
# 14    Balwyn North                         171               1
# 15      Yarraville                         164               1
# ...
